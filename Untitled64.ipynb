# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# طباعة شكل البيانات
print("Train images shape:", train_images.shape)
print("Test images shape:", test_images.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Train images shape: (60000, 28, 28)
# Test images shape: (10000, 28, 28)

# %%
# تطبيع الصور (قيم بين 0 و 1)
train_images = train_images / 255.0
test_images = test_images / 255.0

# تحويل الصور إلى 4D tensor (عدد العينات، العرض، الطول، القنوات)
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9011 - loss: 0.3236 - val_accuracy: 0.9847 - val_loss: 0.0527
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 4ms/step - accuracy: 0.9844 - loss: 0.0507 - val_accuracy: 0.9894 - val_loss: 0.0310
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9897 - loss: 0.0327 - val_accuracy: 0.9890 - val_loss: 0.0342
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9913 - loss: 0.0267 - val_accuracy: 0.9879 - val_loss: 0.0356
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9941 - loss: 0.0176 - val_accuracy: 0.9894 - val_loss: 0.0349
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9954 - loss: 0.0150 - val_accuracy: 0.9915 - val_loss: 0.0292
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.9915 - val_loss: 0.0302
# Epoch 8/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.9913 - loss: 0.0306
# Test accuracy: 0.9912999868392944

# %%
import numpy as np

predictions = model.predict(test_images)

def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i].reshape(28,28)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'
    plt.xlabel(f"Predicted: {predicted_label}", color=color)

plt.figure(figsize=(6,3))
plot_image(0, predictions[0], test_labels, test_images)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# دالة لعرض الصورة مع التوقع
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i].reshape(28,28)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"Predicted: {predicted_label}", color=color)

# عرض 25 صورة مع التوقعات في شبكة 5x5
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plot_image(i, predictions[i], test_labels, test_images)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# %%
cm = confusion_matrix(test_labels, y_pred_classes)

# %%
# توقع الفئات لكل صورة في بيانات الاختبار
y_pred = model.predict(test_images)
# تحويل التوقعات إلى الفئة ذات الاحتمال الأعلى
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
labels = [str(i) for i in range(10)]  # تسميات الفئات من 0 إلى 9

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)  # يمكنك تغيير الألوان حسب الرغبة
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# توقعات النموذج (مثال)
y_pred = model.predict(test_images)
y_pred_classes = np.argmax(y_pred, axis=1)

# حساب مصفوفة الارتباك
cm = confusion_matrix(test_labels, y_pred_classes)

# إعداد شكل الرسم
plt.figure(figsize=(10,8))

# اختيار لوحة ألوان جذابة (يمكنك تغييرها حسب الرغبة)
cmap = sns.color_palette("coolwarm", as_cmap=True)

# رسم مصفوفة الارتباك باستخدام seaborn heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, cbar=True,
            xticklabels=[str(i) for i in range(10)],
            yticklabels=[str(i) for i in range(10)])

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix with Colorful Heatmap')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
